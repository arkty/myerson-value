# %%
from ipywidgets import widgets
from IPython.display import display
matrixInput = widgets.Textarea(
    placeholder='Введи матрицу',
)
calculate = widgets.Button(
    description='Найти вектор'
)
display(widgets.Label(value="Матрица инцидентности"))
display(matrixInput)
display(calculate)
# Out:
# Label(value='Матрица инцидентности')
# Textarea(value='', placeholder='Введи матрицу')
# Button(description='Найти вектор', style=ButtonStyle())
